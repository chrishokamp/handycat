# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace0 = Scatter(
  x=[1, 2, 3, 4],
  y=[10, 15, 13, 17]
)
trace1 = Scatter(
  x=[1, 2, 3, 4],
  y=[16, 5, 11, 9]
)
data = Data([trace0, trace1])

py.iplot(data, filename = 'basic-line')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~chrishokamp/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~chrishokamp/0.embed" height="525px" width="100%"></iframe>

# %%
import os
import json
import codecs

# %%
logdir = '/media/1tb_drive/Dropbox/projects/handycat_postediting_with_Felix/workshop_logs'

# %%
logfiles = [os.path.join(logdir, f) for f in os.listdir(logdir)
            if os.path.isfile(os.path.join(logdir, f))]

# %%
len(logfiles)
# Out:
# 50

# %%
json_logs = [json.loads(codecs.open(f, encoding='utf8').read()) for f in logfiles]

# %%
json_logs[0]
# Out:
# {u'document': {u'Group 3 - Session 1': {u'segments': {u'0': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Pref\xe1cio',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790064633,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Pref\xe1cio',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790077283,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Pref\xe1cio',
#        u'previousValue': u'Pref\xe1cio',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790081036,
#       u'user': {u'name': u'Butterfly'}}],
#     u'1': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Este documento fornece os requisitos de seguran\xe7a para todos <tag> produtos, incluindo:',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790081038,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Este documento fornece os requisitos de seguran\xe7a para todos os produtos, incluindo:',
#        u'previousValue': u'Este documento fornece os requisitos de seguran\xe7a para todos <tag> produtos, incluindo:',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790104674,
#       u'user': {u'name': u'Butterfly'}}],
#     u'10': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Caracter\xedstica do produto',
#        u'segmentId': 10},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790257661,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Caracter\xedstica do produto',
#        u'previousValue': u'Caracter\xedstica do produto',
#        u'segmentId': 10},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790278589,
#       u'user': {u'name': u'Butterfly'}}],
#     u'11': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Termo definido',
#        u'segmentId': 11},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790278591,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Termo definido',
#        u'previousValue': u'Termo definido',
#        u'segmentId': 11},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790280845,
#       u'user': {u'name': u'Butterfly'}}],
#     u'12': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'\xc0 marca\xe7\xe3o dos equipamentos e s\xedmbolos',
#        u'segmentId': 12},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790280847,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Marca\xe7\xe3o do equipamento e s\xedmbolos',
#        u'previousValue': u'\xc0 marca\xe7\xe3o dos equipamentos e s\xedmbolos',
#        u'segmentId': 12},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790299729,
#       u'user': {u'name': u'Butterfly'}}],
#     u'13': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'V\xe1rios s\xedmbolos s\xe3o usados \u200b\u200bpara transmitir mensagens visuais neste manual e no equipamento.',
#        u'segmentId': 13},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790299731,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'V\xe1rios s\xedmbolos s\xe3o usados \u200b\u200bpara transmitir mensagens visuais neste manual e no equipamento.',
#        u'previousValue': u'V\xe1rios s\xedmbolos s\xe3o usados \u200b\u200bpara transmitir mensagens visuais neste manual e no equipamento.',
#        u'segmentId': 13},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790308174,
#       u'user': {u'name': u'Butterfly'}}],
#     u'14': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Os s\xedmbolos seguem a Organiza\xe7\xe3o Internacional de Normaliza\xe7\xe3o (ISO) formato.',
#        u'segmentId': 14},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790308176,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Os s\xedmbolos seguem o formato da Organiza\xe7\xe3o Internacional de Normaliza\xe7\xe3o (ISO) .',
#        u'previousValue': u'Os s\xedmbolos seguem a Organiza\xe7\xe3o Internacional de Normaliza\xe7\xe3o (ISO) formato.',
#        u'segmentId': 14},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790351045,
#       u'user': {u'name': u'Butterfly'}}],
#     u'15': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'perigo da perda geral, podem ocorrer les\xf5es ou danos.',
#        u'segmentId': 15},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790351047,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Perigo geral - podem ocorrer perda, les\xf5es ou danos.',
#        u'previousValue': u'perigo da perda geral, podem ocorrer les\xf5es ou danos.',
#        u'segmentId': 15},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790417291,
#       u'user': {u'name': u'Butterfly'}}],
#     u'16': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Consulte os documentos de acompanhamento ou o texto adjacente.',
#        u'segmentId': 16},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790417292,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Consulte os documentos inclu\xeddos ou o texto adjacente.',
#        u'previousValue': u'Consulte os documentos de acompanhamento ou o texto adjacente.',
#        u'segmentId': 16},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790434348,
#       u'user': {u'name': u'Butterfly'}}],
#     u'17': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Choque el\xe9ctrico perigo de choque.',
#        u'segmentId': 17},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790434350,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Perigo de choque el\xe9ctrico.',
#        u'previousValue': u'Choque el\xe9ctrico perigo de choque.',
#        u'segmentId': 17},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790469179,
#       u'user': {u'name': u'Butterfly'}}],
#     u'18': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Consulte os servi\xe7os de manuten\xe7\xe3o com pessoal de manuten\xe7\xe3o qualificado.',
#        u'segmentId': 18},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790469180,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Para servi\xe7os de manuten\xe7\xe3o  - pessoal de manuten\xe7\xe3o qualificado.',
#        u'previousValue': u'Consulte os servi\xe7os de manuten\xe7\xe3o com pessoal de manuten\xe7\xe3o qualificado.',
#        u'segmentId': 18},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790510547,
#       u'user': {u'name': u'Butterfly'}}],
#     u'19': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Derrubar sobre os perigos Movendo equipamento requer aten\xe7\xe3o especial para evitar a sua queda e ferindo uma pessoa.',
#        u'segmentId': 19},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790510549,
#       u'user': {u'name': u'Butterfly'}}],
#     u'2': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Algumas informa\xe7\xf5es contidas neste documento n\xe3o se aplica a todos <tag> equipamento.',
#        u'segmentId': 2},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790104678,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Algumas informa\xe7\xf5es contidas neste documento n\xe3o se aplicam a todos os equipamentos.',
#        u'previousValue': u'Algumas informa\xe7\xf5es contidas neste documento n\xe3o se aplica a todos <tag> equipamento.',
#        u'segmentId': 2},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790128533,
#       u'user': {u'name': u'Butterfly'}}],
#     u'3': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Consulte as informa\xe7\xf5es que se aplica ao <tag> equipamentos em suas instala\xe7\xf5es e desconsiderar os itens que n\xe3o se aplicam.',
#        u'segmentId': 3},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790128535,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Consulte as informa\xe7\xf5es que se aplicam ao equipamento em suas instala\xe7\xf5es e desconsidere os itens que n\xe3o se aplicam.',
#        u'previousValue': u'Consulte as informa\xe7\xf5es que se aplica ao <tag> equipamentos em suas instala\xe7\xf5es e desconsiderar os itens que n\xe3o se aplicam.',
#        u'segmentId': 3},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790161684,
#       u'user': {u'name': u'Butterfly'}}],
#     u'4': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Os guias do usu\xe1rio para <tag> produtos s\xe3o fornecidos como documentos separados.',
#        u'segmentId': 4},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790161690,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Os guias do usu\xe1rio para os produtos s\xe3o fornecidos como documentos separados.',
#        u'previousValue': u'Os guias do usu\xe1rio para <tag> produtos s\xe3o fornecidos como documentos separados.',
#        u'segmentId': 4},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790183525,
#       u'user': {u'name': u'Butterfly'}}],
#     u'5': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Para obter informa\xe7\xf5es de seguran\xe7a sobre produtos n\xe3o abrangidos neste documento, ligue para o Centro de Suporte T\xe9cnico para <tag> produtos em',
#        u'segmentId': 5},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790183526,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Para obter informa\xe7\xf5es de seguran\xe7a sobre produtos n\xe3o abrangidos neste documento, ligue para o Centro de Suporte T\xe9cnico para produtos em',
#        u'previousValue': u'Para obter informa\xe7\xf5es de seguran\xe7a sobre produtos n\xe3o abrangidos neste documento, ligue para o Centro de Suporte T\xe9cnico para <tag> produtos em',
#        u'segmentId': 5},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790212040,
#       u'user': {u'name': u'Butterfly'}}],
#     u'6': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'<Tag>, se chamando dentro dos Estados Unidos',
#        u'segmentId': 6},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790212043,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Se chamando dentro dos Estados Unidos',
#        u'previousValue': u'<Tag>, se chamando dentro dos Estados Unidos',
#        u'segmentId': 6},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790232268,
#       u'user': {u'name': u'Butterfly'}}],
#     u'7': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'<Tag>, se chamando fora dos Estados Unidos',
#        u'segmentId': 7},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790232269,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'se chamando fora dos Estados Unidos',
#        u'previousValue': u'<Tag>, se chamando fora dos Estados Unidos',
#        u'segmentId': 7},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790241195,
#       u'user': {u'name': u'Butterfly'}}],
#     u'8': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'Termos Definidos',
#        u'segmentId': 8},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790241197,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'Termos Definidos',
#        u'previousValue': u'Termos Definidos',
#        u'segmentId': 8},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790244636,
#       u'user': {u'name': u'Butterfly'}}],
#     u'9': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'currentValue': u'A tabela a seguir identifica os termos definidos utilizados ao longo deste documento para determinados produtos e recursos do produto.',
#        u'segmentId': 9},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790244637,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'typeaheadEditor',
#          u'components': [{u'directiveName': u'typeaheadEditor',
#            u'textName': u'Autocomplete'}],
#          u'defaultComponent': u'typeaheadEditor'}},
#        u'newValue': u'A tabela a seguir identifica os termos definidos utilizados ao longo deste documento para determinados produtos e recursos do produto.',
#        u'previousValue': u'A tabela a seguir identifica os termos definidos utilizados ao longo deste documento para determinados produtos e recursos do produto.',
#        u'segmentId': 9},
#       u'project': {u'_id': u'5870d7ee48980efc50f1caa2',
#        u'name': u'Group 3 - Session 1'},
#       u'time': 1483790257659,
#       u'user': {u'name': u'Butterfly'}}]}},
#   u'Group 3 - Session 2': {u'segments': {u'0': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos possui ou usa?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790616011,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos possui ou usa?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790616013,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos possui ou usa?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790626336,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos possui ou usa?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790626337,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos possui ou usa?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790655538,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.replace',
#       u'data': {u'newTarget': u'Qual dos seguintes tipos de dispositivos POSSUIpossui ou usa?',
#        u'originalTarget': u'Qual dos seguintes tipos de dispositivos possui ou usa?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790666520,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Qual dos seguintes tipos de dispositivos ou usa?',
#        u'originalTarget': u'Qual dos seguintes tipos de dispositivos POSSUIpossui ou usa?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790672039,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Qual dos seguintes tipos de dispositivos ?',
#        u'originalTarget': u'Qual dos seguintes tipos de dispositivos ou usa?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790713401,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.insert',
#       u'data': {u'newTarget': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'originalTarget': u'Qual dos seguintes tipos de dispositivos ?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790731240,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'previousValue': u'Qual dos seguintes tipos de dispositivos possui ou usa?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790734893,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791202374,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791202378,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791202383,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'previousValue': u'Qual dos seguintes tipos de dispositivos POSSUI E USA ?',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791211102,
#       u'user': {u'name': u'Butterfly'}}],
#     u'1': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Selecione todas as op\xe7\xf5es que se aplicam',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790734895,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Selecione todas as op\xe7\xf5es que se aplicam',
#        u'previousValue': u'Selecione todas as op\xe7\xf5es que se aplicam',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790743030,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Selecione todas as op\xe7\xf5es que se aplicam',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791211104,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Selecione todas as op\xe7\xf5es que se aplicam',
#        u'previousValue': u'Selecione todas as op\xe7\xf5es que se aplicam',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791212413,
#       u'user': {u'name': u'Butterfly'}}],
#     u'10': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Por favor, digite o n\xfamero total mais pr\xf3ximo do seu gasto total em <tag>.',
#        u'segmentId': 10},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791366428,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.replace',
#       u'data': {u'newTarget': u'Por favor, digite o n\xfamero inteiro mais pr\xf3ximo do seu gasto total em .',
#        u'originalTarget': u'Por favor, digite o n\xfamero total mais pr\xf3ximo do seu gasto total em <tag>.'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791385612,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Por favor, digite o n\xfamero inteiro mais pr\xf3ximo do seu gasto total em .',
#        u'previousValue': u'Por favor, digite o n\xfamero total mais pr\xf3ximo do seu gasto total em <tag>.',
#        u'segmentId': 10},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791387772,
#       u'user': {u'name': u'Butterfly'}}],
#     u'11': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Por exemplo, se seu gasto total \xe9 de 12,99, por favor digite 13.',
#        u'segmentId': 11},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791387773,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Por exemplo, se seu gasto total \xe9 de 12,99, por favor digite 13.',
#        u'previousValue': u'Por exemplo, se seu gasto total \xe9 de 12,99, por favor digite 13.',
#        u'segmentId': 11},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791395753,
#       u'user': {u'name': u'Butterfly'}}],
#     u'12': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Pensando em cada uma das categorias abaixo, por favor, estimar o seu gasto total em cada categoria ao longo dos \xfaltimos 12 meses:',
#        u'segmentId': 12},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483791395755,
#       u'user': {u'name': u'Butterfly'}}],
#     u'2': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'E qual dos seguintes tipos de dispositivos que voc\xea usa atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'segmentId': 2},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790743031,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea usa atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos que voc\xea usa atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790757108,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.insert',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea usa atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790875008,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790879531,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790883520,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790885218,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, , no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790909040,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui,, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, , no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790914540,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui,, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790918275,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.move',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, no trabalho ou lugar p\xfablico em um ou seja, bibliotecas ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790955027,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'postEditor.move',
#       u'data': {u'newTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, no trabalho ou em um lugar p\xfablico ou seja, bibliotecas ou internet caf\xe9)?',
#        u'originalTarget': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, no trabalho ou lugar p\xfablico em um ou seja, bibliotecas ou internet caf\xe9)?'},
#       u'project': {u'_id': u'5870da1a48980efc50f1cab7',
#        u'name': u'Group 3 - Session 2'},
#       u'time': 1483790967410,
#       u'user': {u'name': u'Butterfly'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'E qual dos seguintes tipos de dispositivos voc\xea USA ACTUALMENTE PARA ACESSAR a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, no trabalho ou em um lugar p\xfablico ou seja, bibliotecas ou internet caf\xe9)?',
#        u'previousValue': u'E qual dos seguintes tipos de dispositivos que voc\xea usa atualmente para acessar a Internet em casa, no trabalho ou em outros lugares (incluindo os dispositivos que voc\xea n\xe3o possui, pessoalmente, no trabalho ou em um ou seja, bibliotecas lugar p\xfablico ou internet caf\xe9)?',
# ...
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Mantenha as suas superf\xedcies de mesa, laptop e teclado limpas de sujeira e poeira com os molhadas e superf\xedcie seca toalhetes de limpeza.',
#        u'previousValue': u'Mantenha as suas superf\xedcies de mesa, laptop e teclado limpo de sujeira e poeira com as <tag> molhadas e superf\xedcie seca toalhetes de limpeza.',
#        u'segmentId': 6},
#       u'project': {u'_id': u'5870dea148980efc50f1cad5',
#        u'name': u'Group 3 - Session 4'},
#       u'time': 1483792098124,
#       u'user': {u'name': u'Butterfly'}}]}},
#   u'Session 0 - Project 0 - Post Editor': {u'segments': {u'0': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789699839,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.',
#        u'originalTarget': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789707073,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.',
#        u'originalTarget': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789713328,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.',
#        u'originalTarget': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789716722,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.',
#        u'previousValue': u'Voc\xea pode usar o teclado para digitar caracteres alfanum\xe9ricos e s\xedmbolos.',
#        u'segmentId': 0},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789720724,
#       u'user': {u'name': u'CDuarte'}}],
#     u'1': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Por exemplo, voc\xea pode adicionar entradas para os contatos, escrever mensagens ou agendar eventos no calend\xe1rio.',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789720727,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Por exemplo, voc\xea pode adicionar entradas para os contatos, escrever mensagens ou agendar eventos no calend\xe1rio.',
#        u'originalTarget': u'Por exemplo, voc\xea pode adicionar entradas para os contatos, escrever mensagens ou agendar eventos no calend\xe1rio.'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789728707,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Por exemplo, voc\xea pode adicionar entradas para os contatos, escrever mensagens ou agendar eventos no calend\xe1rio.',
#        u'previousValue': u'Por exemplo, voc\xea pode adicionar entradas para os contatos, escrever mensagens ou agendar eventos no calend\xe1rio.',
#        u'segmentId': 1},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789751069,
#       u'user': {u'name': u'CDuarte'}}],
#     u'2': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Voc\xea pode percorrer esta lista e selecione o caractere desejado.',
#        u'segmentId': 2},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789751070,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.replace',
#       u'data': {u'newTarget': u'Voc\xea pode percorrer esta lista e selecionarselecione o caractere desejado.',
#        u'originalTarget': u'Voc\xea pode percorrer esta lista e selecione o caractere desejado.'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789774035,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Voc\xea pode percorrer esta lista e selecionarselecione o caractere desejado.',
#        u'previousValue': u'Voc\xea pode percorrer esta lista e selecione o caractere desejado.',
#        u'segmentId': 2},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789804909,
#       u'user': {u'name': u'CDuarte'}}],
#     u'3': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Pare quando voc\xea v\xea um "h" na tela.',
#        u'segmentId': 3},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789804912,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Pare quando voc\xea v\xea um "h" na tela.',
#        u'previousValue': u'Pare quando voc\xea v\xea um "h" na tela.',
#        u'segmentId': 3},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789810586,
#       u'user': {u'name': u'CDuarte'}}],
#     u'4': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Depois de inserir a primeira letra, voc\xea pode pressionar diretamente outra tecla (exceto Enviar) para inserir a pr\xf3xima letra.',
#        u'segmentId': 4},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789810587,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Depois de inserir a primeira letra, voc\xea pode pressionar diretamente outra tecla (exceto Enviar) para inserir a pr\xf3xima letra.',
#        u'previousValue': u'Depois de inserir a primeira letra, voc\xea pode pressionar diretamente outra tecla (exceto Enviar) para inserir a pr\xf3xima letra.',
#        u'segmentId': 4},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789817608,
#       u'user': {u'name': u'CDuarte'}}],
#     u'5': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Se a pr\xf3xima letra desejada estiver na mesma tecla que a actual, aguarde at\xe9 que o cursor aparece \xe0 direita da letra atual e, em seguida, voc\xea pode digitar o pr\xf3ximo.',
#        u'segmentId': 5},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789817611,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'Se a pr\xf3xima letra desejada estiver na mesma tecla que a actual, aguarde at\xe9 que o cursor aparece \xe0 direita da letra atual e, em seguida, voc\xea pode digitar o pr\xf3ximo.',
#        u'originalTarget': u'Se a pr\xf3xima letra desejada estiver na mesma tecla que a actual, aguarde at\xe9 que o cursor aparece \xe0 direita da letra atual e, em seguida, voc\xea pode digitar o pr\xf3ximo.'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789829112,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Se a pr\xf3xima letra desejada estiver na mesma tecla que a actual, aguarde at\xe9 que o cursor aparece \xe0 direita da letra atual e, em seguida, voc\xea pode digitar o pr\xf3ximo.',
#        u'segmentId': 5},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789855671,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'Se a pr\xf3xima letra desejada estiver na mesma tecla que a actual, aguarde at\xe9 que o cursor aparece \xe0 direita da letra atual e, em seguida, voc\xea pode digitar o pr\xf3ximo.',
#        u'previousValue': u'Se a pr\xf3xima letra desejada estiver na mesma tecla que a actual, aguarde at\xe9 que o cursor aparece \xe0 direita da letra atual e, em seguida, voc\xea pode digitar o pr\xf3ximo.',
#        u'segmentId': 5},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789858309,
#       u'user': {u'name': u'CDuarte'}}],
#     u'6': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'|||UNTRANSLATED_CONTENT_START|||You can access the Settings screen by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||',
#        u'segmentId': 6},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789835309,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'can access the Settings by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||',
#        u'originalTarget': u'|||UNTRANSLATED_CONTENT_START|||You can access the Settings screen by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789847032,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'access the Settings by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||',
#        u'originalTarget': u'can access the Settings by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789848848,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'postEditor.delete',
#       u'data': {u'newTarget': u'the Settings by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||',
#        u'originalTarget': u'access the Settings by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||'},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789850632,
#       u'user': {u'name': u'CDuarte'}},
#      {u'action': u'segment-complete',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'newValue': u'the Settings by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||',
#        u'previousValue': u'|||UNTRANSLATED_CONTENT_START|||You can access the Settings screen by selecting Settings from the main menu.|||UNTRANSLATED_CONTENT_END|||',
#        u'segmentId': 6},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789855670,
#       u'user': {u'name': u'CDuarte'}}],
#     u'7': [{u'action': u'change-segment',
#       u'data': {u'configuration': {u'target': {u'activeComponent': u'postEditor',
#          u'components': [{u'directiveName': u'postEditor',
#            u'textName': u'Post Editor'}],
#          u'defaultComponent': u'postEditor'}},
#        u'currentValue': u'Configura\xe7\xf5es de Telefone...',
#        u'segmentId': 7},
#       u'project': {u'_id': u'5870d68048980efc50f1ca8f',
#        u'name': u'Session 0 - Project 0 - Post Editor'},
#       u'time': 1483789858311,
#       u'user': {u'name': u'CDuarte'}}]}}}}
